# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
import csv
pd.options.display.max_columns = None

# %%
TS_CSV = './644_nab_s_ts.csv'
CONFIG_CSV='./644_nab_s_regret_out.csv'

# %%
df = pd.read_csv(TS_CSV)
df.head()
# Out:
#    Timestamp  run_warm_up     run_1     run_2     run_3     run_4     run_5  \
# 0          0     0.003079  0.010911  0.006508  0.004529  0.004442  0.011391
# 1          1     0.270021  0.287181  0.272675  0.276795  0.201071  0.320877
# 2          2     0.415445  0.469619  0.421502  0.391446  0.419062  0.468351
# 3          3     0.682802  0.738797  0.689379  0.658719  0.683470  0.736620
# 4          4     0.807075  0.867100  0.819437  0.798737  0.796252  0.873394
#
#       run_6     run_7     run_8     run_9    run_10    run_11    run_12  \
# 0  0.007971  0.005191  0.005240  0.000795  0.005379  0.006427  0.004545
# 1  0.299166  0.200932  0.257319  0.263714  0.206006  0.278499  0.255606
# 2  0.427884  0.418167  0.407094  0.428951  0.430924  0.442986  0.394580
# 3  0.687857  0.687951  0.670165  0.705052  0.699754  0.704676  0.659209
# 4  0.849418  0.795568  0.787019  0.801894  0.807734  0.832382  0.781253
#
#      run_13    run_14    run_15    run_16    run_17    run_18    run_19  \
# 0  0.008160  0.008208  0.006518  0.004555  0.008140  0.009827  0.004685
# 1  0.283174  0.283703  0.280007  0.256398  0.302021  0.312192  0.265917
# 2  0.398674  0.434684  0.433457  0.408190  0.419101  0.448515  0.413368
# 3  0.655491  0.704170  0.696322  0.673663  0.679454  0.718912  0.679704
# 4  0.814742  0.834224  0.824978  0.791703  0.822301  0.872486  0.797660
#
#      run_20    run_21    run_22    run_23    run_24    run_25    run_26  \
# 0  0.002777  0.008189  0.004721  0.004591  0.008169  0.000415  0.003322
# 1  0.262569  0.286240  0.263328  0.264515  0.274589  0.262935  0.260035
# 2  0.423789  0.418634  0.411399  0.399320  0.429915  0.389126  0.405968
# 3  0.686653  0.676719  0.679811  0.662804  0.693515  0.653268  0.669305
# 4  0.804765  0.823924  0.794315  0.795843  0.819187  0.782668  0.791009
#
#      run_27    run_28    run_29    run_30    run_31    run_32    run_33  \
# 0  0.008166  0.003319  0.003351  0.003121  0.003348  0.003309  0.003351
# 1  0.304752  0.204517  0.204705  0.286765  0.262507  0.259483  0.200069
# 2  0.431858  0.432861  0.433457  0.399336  0.417709  0.409650  0.423247
# 3  0.698099  0.692256  0.697687  0.658093  0.680281  0.668780  0.689547
# 4  0.843416  0.804730  0.811163  0.809191  0.808766  0.793060  0.800557
#
#      run_34    run_35    run_36    run_37    run_38    run_39    run_40  \
# 0  0.003345  0.003335  0.003342  0.003134  0.003351  0.009782  0.003170
# 1  0.264785  0.255840  0.205334  0.264191  0.202833  0.285750  0.265787
# 2  0.412366  0.401925  0.432815  0.403421  0.413105  0.485345  0.425911
# 3  0.681407  0.663913  0.698936  0.669117  0.677751  0.746314  0.684879
# 4  0.796797  0.790094  0.801794  0.795749  0.791324  0.853048  0.809320
#
# 2  0.418968  0.412187  0.417135  0.422806  0.416843  0.423705  0.412476
# 3  0.680911  0.673958  0.685573  0.679811  0.677861  0.692480  0.672670
# 4  0.805878  0.795843  0.797754  0.801502  0.800350  0.808269  0.805301
#
#      run_90    run_91    run_92    run_93    run_94    run_95    run_96  \
# 0  0.003173  0.003267  0.003371  0.003355  0.003377  0.003348  0.003345
# 1  0.265528  0.262254  0.265742  0.262033  0.262780  0.258578  0.204578
# 2  0.423497  0.412797  0.414218  0.424509  0.417330  0.418673  0.431420
# 3  0.687416  0.673160  0.676618  0.688717  0.680982  0.682474  0.695679
# 4  0.806066  0.794072  0.802270  0.802206  0.804431  0.802718  0.804068
#
#      run_97    run_98    run_99   run_100  run_default_jemalloc  \
# 0  0.003303  0.006333  0.003345  0.003309              0.003076
# 1  0.263821  0.291330  0.262987  0.201113              0.270135
# 2  0.415243  0.419675  0.432280  0.417511              0.414656
# 3  0.676229  0.687253  0.691491  0.682082              0.683302
# 4  0.806611  0.833744  0.804817  0.796830              0.802605
#
#    run_default_tcmalloc
# 0              0.006197
# 1              0.274498
# 2              0.408096
# 3              0.670370
# 4              0.816092

# %%
configs = pd.read_csv(CONFIG_CSV)
configs.head()
# Out:
#    je_cache_oblivious  je_dirty_decay_ms     je_dss  \
# 0               False               4166  secondary
# 1                True              26222   disabled
# 2                True              19411  secondary
# 3               False              46965   disabled
# 4               False              15123   disabled
#
#    je_lg_extent_max_active_fit  je_lg_tcache_max  je_max_background_threads  \
# 0                           12                20                         35
# 1                           15                15                         51
# 2                            5                 2                         72
# 3                           23                26                         14
# 4                           19                27                         21
#
#   je_metadata_thp  je_mutex_max_spin  je_muzzy_decay_ms  je_narenas  \
# 0          always               1829              37945         108
# 1          always               1008              21751         380
# 2            auto                161               7050         482
# 3        disabled               1740              26760         314
# 4            auto                315                726         410
#
#    je_oversize_threshold je_percpu_arena  je_retain   je_thp  \
# 0               31713413          phycpu       True   always
# 1               15821071        disabled      False   always
# 2                7610798          percpu       True    never
# 3               23502888          percpu      False  default
# 4                 216827          percpu       True   always
#
#    je_trust_madvise        rss
# 0              True  34.366039
# 1             False  15.047050
# 2             False  -3.908326
# 3              True  -3.130642
# 4              True  40.333047

# %%
configs.nsmallest(5, 'rss')
# Out:
#     je_cache_oblivious  je_dirty_decay_ms     je_dss  \
# 8                False              22678    primary
# 50               False              22678    primary
# 46               False              22678   disabled
# 11               False              28366  secondary
# 63               False              22678    primary
#
#     je_lg_extent_max_active_fit  je_lg_tcache_max  je_max_background_threads  \
# 8                             2                12                         18
# 50                           10                12                          8
# 46                            8                12                         18
# 11                           13                 4                         36
# 63                           10                12                         18
#
#    je_metadata_thp  je_mutex_max_spin  je_muzzy_decay_ms  je_narenas  \
# 8             auto                564               5188         248
# 50        disabled                564               3283         248
# 46            auto                564                196         248
# 11        disabled                662              15983         135
# 63        disabled                564               4836         248
#
#     je_oversize_threshold je_percpu_arena  je_retain   je_thp  \
# 8                11042583          phycpu      False  default
# 50               11042583          phycpu       True    never
# 46               11042583          percpu       True    never
# 11                2963382          phycpu       True    never
# 63                2961771          phycpu       True  default
#
#     je_trust_madvise        rss
# 8              False -26.466122
# 50             False -14.486166
# 46              True -13.689304
# 11             False -13.009065
# 63              True -12.738937

# %%
smallest_indices = configs.nsmallest(3, 'rss').index.tolist()

# Step 2: Map these indices to the corresponding column names in `df`
selected_columns = [f'run_{i+1}' for i in smallest_indices if f'run_{i}' in df.columns]
selected_columns
# Out:
# ['run_9', 'run_51', 'run_47']

# %%
# Read the CSV file into a pandas DataFrame
df = pd.read_csv(TS_CSV)

# Extract timestamps and RSS values for each run
timestamps = df['Timestamp']
warmup = df['run_warm_up']
default = df['run_default_jemalloc']
tc_default = df['run_default_tcmalloc']

# plt.plot(timestamps, warmup, label='warm_up')
plt.plot(timestamps, default, label='default jemalloc')
# plt.plot(timestamps, tc_default, label='default tcmalloc')
for column in selected_columns:  # Skip 'Timestamp'
    plt.plot(timestamps, df[column], label=column)

# Customize plot
plt.xlabel('Time (s)')
plt.ylabel('RSS (GB)')
plt.title('RSS vs Time for Multiple Runs')
plt.legend()
plt.grid(True)

# Display plot
plt.show()

# %%
# Out:
#    je_background_thread  je_cache_oblivious  je_dirty_decay_ms     je_dss  \
# 0                 False                True              10000  secondary
#
#    je_lg_extent_max_active_fit  je_lg_tcache_max  je_max_background_threads  \
# 0                            6                15                         40
#
#   je_metadata_thp je_mutex_max_spin  je_muzzy_decay_ms  je_narenas  \
# 0        disabled              1600              10000         160
#
#    je_oversize_threshold je_percpu_arena  je_retain  je_tcache   je_thp  \
# 0                8388608         default       True       True  default
#
#    je_trust_madvise  rss
# 0             False    0

# %%
default_conf_dict = {'je_cache_oblivious': True, 'je_metadata_thp': 'disabled', 'je_trust_madvise': False, 'je_retain': True, 'je_dss': 'secondary', 'je_narenas': 160, 'je_oversize_threshold': 8388608, 'je_background_thread': False, 'je_max_background_threads': 40, 'je_dirty_decay_ms': 10000, 'je_muzzy_decay_ms': 10000, 'je_lg_extent_max_active_fit': 6, 'je_tcache': True, 'je_lg_tcache_max': 15, 'je_thp': 'default', 'je_percpu_arena': 'default', 'je_mutex_max_spin': '1600'}
default_conf_dict = dict(sorted(default_conf_dict.items()))
default_conf_dict.update({'rss': 0})
default_conf_df = pd.DataFrame([default_conf_dict])
default_conf_df

smallest_configs = configs.nsmallest(3, 'rss').copy()

# Add an identifier column to distinguish these configurations clearly
smallest_configs['config'] = selected_columns

# Add identifier to default configuration
default_conf_df['config'] = 'default'

# Concatenate vertically to compare clearly
comparison_df = pd.concat([smallest_configs, default_conf_df], ignore_index=True)

# Move 'config' column to the front and 'rss' column to the end for readability
cols = ['config'] + [col for col in comparison_df.columns if col not in ['config', 'rss']] + ['rss']
comparison_df = comparison_df[cols]

comparison_df.T
# Out:
#                                      0          1          2          3
# config                           run_9     run_51     run_47    default
# je_cache_oblivious               False      False      False       True
# je_dirty_decay_ms                22678      22678      22678      10000
# je_dss                         primary    primary   disabled  secondary
# je_lg_extent_max_active_fit          2         10          8          6
# je_lg_tcache_max                    12         12         12         15
# je_max_background_threads           18          8         18         40
# je_metadata_thp                   auto   disabled       auto   disabled
# je_mutex_max_spin                  564        564        564       1600
# je_muzzy_decay_ms                 5188       3283        196      10000
# je_narenas                         248        248        248        160
# je_oversize_threshold         11042583   11042583   11042583    8388608
# je_percpu_arena                 phycpu     phycpu     percpu    default
# je_retain                        False       True       True       True
# je_thp                         default      never      never    default
# je_trust_madvise                 False      False       True      False
# je_background_thread               NaN        NaN        NaN      False
# je_tcache                          NaN        NaN        NaN       True
# rss                         -26.466122 -14.486166 -13.689304        0.0

# %%
# Out:
#                                      0          1          2          3
# je_cache_oblivious               False      False      False       True
# je_dirty_decay_ms                22678      22678      22678      10000
# je_dss                         primary    primary   disabled  secondary
# je_lg_extent_max_active_fit          2         10          8          6
# je_lg_tcache_max                    12         12         12         15
# je_max_background_threads           18          8         18         40
# je_metadata_thp                   auto   disabled       auto   disabled
# je_mutex_max_spin                  564        564        564       1600
# je_muzzy_decay_ms                 5188       3283        196      10000
# je_narenas                         248        248        248        160
# je_oversize_threshold         11042583   11042583   11042583    8388608
# je_percpu_arena                 phycpu     phycpu     percpu    default
# je_retain                        False       True       True       True
# je_thp                         default      never      never    default
# je_trust_madvise                 False      False       True      False
# rss                         -26.466122 -14.486166 -13.689304        NaN
# config                          best_1     best_2     best_3    default
# je_background_thread               NaN        NaN        NaN      False
# je_tcache                          NaN        NaN        NaN       True
# regret                             NaN        NaN        NaN        0.0

# %%
smallest_indices = configs.nsmallest(3, 'rss').index.tolist()

# Step 2: Map these indices to the corresponding column names in `df`
selected_columns = [f'run_{i+1}' for i in smallest_indices if f'run_{i+1}' in df.columns]

# Step 3: Generate separate plots for each selected column
for column in selected_columns:
    # Calculate regret for the current column
    regret =  (df[column] - df['run_default_jemalloc'])
    
    # Create a new plot for this column
    fig, ax = plt.subplots(figsize=(8, 5))
    
    # Plot the regret against the index
    ax.plot(regret.index, regret.values, marker='o', label=f'Regret ({column})')
    
    # Customize the plot
    ax.set_title(f'Regret vs Timestamp for {column}')
    ax.set_xlabel('Timestamp')
    ax.set_ylabel('Regret')
    ax.legend()
    ax.grid(True, linestyle='--', alpha=0.7)
    
    # Display the plot
    plt.tight_layout()
    plt.show()

# %%
score_cols = df.columns[-1:].copy()

numeric_cols = df.select_dtypes(include=['float64', 'int64']).columns.tolist()
numeric_cols = [e for e in numeric_cols if e not in score_cols]
categorical_cols = df.select_dtypes(include=['bool', 'object']).columns.tolist()

# Plotting the graphs
score_col = 'rss'
for col in numeric_cols:
    plt.figure(figsize=(8, 6))
    plt.scatter(df[col], df[score_col], marker='o')
    plt.title(f'Plot {col}')
    plt.xlabel(col)
    plt.ylabel(score_col)
    plt.grid(True)
    plt.show()

for col in categorical_cols:
    plt.figure(figsize=(8, 6))
    # df.boxplot(column=score_col, by=col, grid=False, patch_artist=False, showfliers=False)
    # plt.scatter(df[col], df[score_col], marker='o')
    sns.boxplot(x=col, y=score_col, data=df, color='lightgray', boxprops=dict(facecolor='none', edgecolor='black', linewidth=1), fliersize=0)
    sns.scatterplot(x=col, y=score_col, data=df, color='blue', alpha=0.6)
    plt.title(f'Plot {col}')
    plt.suptitle('')
    plt.xlabel(col)
    plt.ylabel(score_col)
    plt.grid(True)
    plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/tm-venv/lib/python3.10/site-packages/pandas/core/indexes/base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'rss'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[18], line 11
#       9 for col in numeric_cols:
#      10     plt.figure(figsize=(8, 6))
# ---> 11     plt.scatter(df[col], df[score_col], marker='o')
#      12     plt.title(f'Plot {col}')
#      13     plt.xlabel(col)
#
# File ~/tm-venv/lib/python3.10/site-packages/pandas/core/frame.py:4102, in DataFrame.__getitem__(self, key)
#    4100 if self.columns.nlevels > 1:
#    4101     return self._getitem_multilevel(key)
# -> 4102 indexer = self.columns.get_loc(key)
#    4103 if is_integer(indexer):
#    4104     indexer = [indexer]
#
# File ~/tm-venv/lib/python3.10/site-packages/pandas/core/indexes/base.py:3812, in Index.get_loc(self, key)
#    3807     if isinstance(casted_key, slice) or (
#    3808         isinstance(casted_key, abc.Iterable)
#    3809         and any(isinstance(x, slice) for x in casted_key)
#    3810     ):
#    3811         raise InvalidIndexError(key)
# -> 3812     raise KeyError(key) from err
#    3813 except TypeError:
#    3814     # If we have a listlike key, _check_indexing_error will raise
#    3815     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3816     #  the TypeError.
#    3817     self._check_indexing_error(key)
#
# KeyError: 'rss'
