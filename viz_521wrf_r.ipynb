# %%
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

# %%
df = pd.read_csv('./521_wrf_r_out.csv')
default_rss = 563.04297

# %%
df.head()
# Out:
#    je_background_thread  je_cache_oblivious  je_dirty_decay_ms     je_dss  \
# 0                 False                True               2176    primary
# 1                  True               False              45519   disabled
# 2                  True                True              17131  secondary
# 3                 False               False              35472   disabled
# 4                 False                True              41567    primary
#
#    je_lg_extent_max_active_fit  je_lg_tcache_max  je_max_background_threads  \
# 0                            4                20                         40
# 1                           23                 4                         67
# 2                           15                13                          7
# 3                           11                25                         58
# 4                            9                19                         19
#
#   je_metadata_thp  je_muzzy_decay_ms  je_narenas  je_oversize_threshold  \
# 0        disabled              28329         321               17771142
# 1          always              19134         235                3847052
# 2            auto               9038          86               14605318
# 3          always              43497         631               32195848
# 4            auto               2634         241               11537645
#
#   je_percpu_arena  je_retain  je_tcache   je_thp  je_trust_madvise        rss
# 0        disabled       True      False  default             False  587.90625
# 1          phycpu      False       True    never              True  583.00000
# 2          percpu       True      False   always             False  625.97656
# 3        disabled      False       True  default              True  594.81250
# 4          percpu       True       True  default              True  571.89453

# %%
df.nsmallest(10, 'rss')
# Out:
#     je_background_thread  je_cache_oblivious  je_dirty_decay_ms     je_dss  \
# 45                 False               False              49172    primary
# 31                 False               False              49172   disabled
# 48                 False               False              49172  secondary
# 30                 False               False              49172    primary
# 36                 False               False              49172   disabled
# 47                 False               False              49172    primary
# 26                 False               False              49172  secondary
# 33                 False               False              49172   disabled
# 42                 False               False              49172    primary
# 49                 False                True              49172    primary
#
#     je_lg_extent_max_active_fit  je_lg_tcache_max  je_max_background_threads  \
# 45                           16                 6                         71
# 31                           16                 6                         73
# 48                           11                 8                         73
# 30                           16                 8                         73
# 36                           16                 6                         70
# 47                           16                 7                         72
# 26                           20                 7                         71
# 33                           20                 7                         75
# 42                           16                13                         74
# 49                           18                 6                         71
#
#    je_metadata_thp  je_muzzy_decay_ms  je_narenas  je_oversize_threshold  \
# 45        disabled              46958          35                  22047
# 31        disabled              45726         219                  17551
# 48        disabled              33590         191                  17551
# 30        disabled              46979          68                 252484
# 36            auto              48802         226                  22047
# 47        disabled              45726          32                  17551
# 26            auto              48802         255                 758347
# 33            auto              48802         193                  10736
# 42        disabled              45774         203                  14129
# 49            auto              46958          35                  22047
#
#    je_percpu_arena  je_retain  je_tcache je_thp  je_trust_madvise        rss
# 45        disabled      False      False  never             False  537.78125
# 31        disabled      False      False  never             False  538.46094
# 48        disabled      False      False  never             False  538.51172
# 30          percpu       True      False  never             False  538.62109
# 36          percpu      False      False  never             False  538.92578
# 47          percpu      False       True  never              True  539.42969
# 26          percpu       True       True  never             False  540.66016
# 33        disabled       True       True  never             False  549.21094
# 42          percpu       True      False  never             False  549.32422
# 49        disabled      False      False  never             False  550.03516

# %%
df.nlargest(5, 'rss')
# Out:
#     je_background_thread  je_cache_oblivious  je_dirty_decay_ms     je_dss  \
# 9                   True               False              22180    primary
# 34                  True                True              49172    primary
# 19                 False               False              38428  secondary
# 29                  True               False               8160   disabled
# 13                  True               False              34062  secondary
#
#     je_lg_extent_max_active_fit  je_lg_tcache_max  je_max_background_threads  \
# 9                             2                14                         43
# 34                            3                 2                         73
# 19                            3                 7                         10
# 29                            4                 6                         72
# 13                            7                 9                         64
#
#    je_metadata_thp  je_muzzy_decay_ms  je_narenas  je_oversize_threshold  \
# 9           always              44624         137               21926461
# 34            auto              40622         150                  17551
# 19          always              31824         520               30771062
# 29            auto              33667         192               18165599
# 13          always              23447         537               15840344
#
#    je_percpu_arena  je_retain  je_tcache   je_thp  je_trust_madvise  \
# 9           phycpu       True      False  default             False
# 34          percpu      False       True    never              True
# 19        disabled       True      False   always              True
# 29          percpu       True       True    never              True
# 13          phycpu       True       True   always              True
#
#            rss
# 9   1560.78906
# 34  1344.93359
# 19   754.53125
# 29   675.80859
# 13   640.42188

# %%
default_conf_dict = {'je_cache_oblivious': True, 'je_metadata_thp': 'disabled', 'je_trust_madvise': False, 'je_retain': True, 'je_dss': 'secondary', 'je_narenas': 160, 'je_oversize_threshold': 8388608, 'je_background_thread': False, 'je_max_background_threads': 40, 'je_dirty_decay_ms': 10000, 'je_muzzy_decay_ms': 10000, 'je_lg_extent_max_active_fit': 6, 'je_tcache': True, 'je_lg_tcache_max': 15, 'je_thp': 'default', 'je_percpu_arena': 'default'}
default_conf_dict = dict(sorted(default_conf_dict.items()))
default_conf_dict.update({'rss': default_rss})
default_conf_df = pd.DataFrame([default_conf_dict])
default_conf_df
# Out:
#    je_background_thread  je_cache_oblivious  je_dirty_decay_ms     je_dss  \
# 0                 False                True              10000  secondary
#
#    je_lg_extent_max_active_fit  je_lg_tcache_max  je_max_background_threads  \
# 0                            6                15                         40
#
#   je_metadata_thp  je_muzzy_decay_ms  je_narenas  je_oversize_threshold  \
# 0        disabled              10000         160                8388608
#
#   je_percpu_arena  je_retain  je_tcache   je_thp  je_trust_madvise        rss
# 0         default       True       True  default             False  563.04297

# %%
# Get max and min RSS rows
max_row = df.loc[[df['rss'].idxmax()]]  # Keep as DataFrame
min_row = df.loc[[df['rss'].idxmin()]]
default_row = default_conf_df.iloc[0]

# Concatenate and transpose to create vertical comparison
comparison_df = pd.concat([min_row, default_conf_df]).T
comparison_df.columns = ['Min RSS', 'Default RSS']  # Rename columns

# %%
comparison_df
# Out:
#                                Min RSS Default RSS
# je_background_thread             False       False
# je_cache_oblivious               False        True
# je_dirty_decay_ms                49172       10000
# je_dss                         primary   secondary
# je_lg_extent_max_active_fit         16           6
# je_lg_tcache_max                     6          15
# je_max_background_threads           71          40
# je_metadata_thp               disabled    disabled
# je_muzzy_decay_ms                46958       10000
# je_narenas                          35         160
# je_oversize_threshold            22047     8388608
# je_percpu_arena               disabled     default
# je_retain                        False        True
# je_tcache                        False        True
# je_thp                           never     default
# je_trust_madvise                 False       False
# rss                          537.78125   563.04297

# %%
plt.figure(figsize=(10, 8))
plt.plot(df.index, df['rss'], marker='o')
plt.ylim(bottom=0)

min_rss = df['rss'].min()
vertical_space = abs(default_rss - min_rss)
higher_line = max(default_rss, min_rss)
lower_line = min(default_rss, min_rss)

offset = (plt.ylim()[1] - plt.ylim()[0]) * 0.02  # 2% of y-axis range

if vertical_space < offset * 2:
    plt.axhline(y=default_rss, color='orange', linestyle='--')
    plt.text(plt.xlim()[1], higher_line + offset, f'{"Default" if higher_line == default_rss else "Min"} RSS:\n{higher_line:.5f}', 
             verticalalignment='bottom', 
             horizontalalignment='left')
    
    plt.axhline(y=min_rss, color='green', linestyle='--')
    plt.text(plt.xlim()[1], lower_line - offset, f'{"Default" if lower_line == default_rss else "Min"} RSS:\n{lower_line:.5f}', 
             verticalalignment='top', 
             horizontalalignment='left')

# Customize the plot
plt.title('RSS vs Iteration #')
plt.xlabel('Iteration #')
plt.ylabel('RSS')
plt.grid(True)

# Display the plot
#plt.tight_layout()
plt.show()

# %%
percent_diff = 100 * (default_rss - df['rss'].min()) / default_rss
percent_diff
# Out:
# np.float64(4.486641579061003)

# %%
score_cols = df.columns[-1:].copy()

numeric_cols = df.select_dtypes(include=['float64', 'int64']).columns.tolist()
numeric_cols = [e for e in numeric_cols if e not in score_cols]
categorical_cols = df.select_dtypes(include=['bool', 'object']).columns.tolist()

# Plotting the graphs
score_col = 'rss'
for col in numeric_cols:
    plt.figure(figsize=(8, 6))
    plt.scatter(df[col], df[score_col], marker='o')
    plt.title(f'Plot {col}')
    plt.xlabel(col)
    plt.ylabel(score_col)
    plt.grid(True)
    plt.show()

for col in categorical_cols:
    plt.figure(figsize=(8, 6))
    # df.boxplot(column=score_col, by=col, grid=False, patch_artist=False, showfliers=False)
    # plt.scatter(df[col], df[score_col], marker='o')
    sns.boxplot(x=col, y=score_col, data=df, color='lightgray', boxprops=dict(facecolor='none', edgecolor='black', linewidth=1), fliersize=0)
    sns.scatterplot(x=col, y=score_col, data=df, color='blue', alpha=0.6)
    plt.title(f'Plot {col}')
    plt.suptitle('')
    plt.xlabel(col)
    plt.ylabel(score_col)
    plt.grid(True)
    plt.show()
